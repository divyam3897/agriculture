# %%
import glob
import numpy as np
import PIL
from PIL import Image
from collections import Counter
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import SGD
from keras.utils import np_utils
from sklearn.model_selection import StratifiedShuffleSplit, train_test_split
from sklearn.metrics import accuracy_score
from keras import backend as K
K.set_image_dim_ordering('th')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Understand the image data

# %%
good_im = Image.open("/home/divyam/agriculture/cottonPests/goodrice/1.jpg")
bad_im = Image.open("/home/divyam/agriculture/cottonPests/bad/11.jpg")

# %%
good_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194 at 0x7F27BEB37630>

# %%
bad_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=440x330 at 0x7F27BEB376D8>

# %%
good_im.size
# Out:
# (259, 194)

# %%
good_array = np.array(good_im.getdata())

# %%
good_array.shape
# Out:
# (50246, 3)

# %% [markdown]
# ### Keras example input data for CNN

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
# 3 RBG, 32*32 Image
X_train.shape
# Out:
# (50000, 3, 32, 32)

# %% [markdown]
# ### Process the images

# %%
# need to resize image so that numpy concat works
resized_cat = cat_im.resize((100, 100))
resized_cat
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FDA12333B38>

# %%
np.array(resized_cat).shape
# Out:
# (100, 100, 3)

# %%
PIL.Image.fromarray(np.array(resized_cat).T[1])
# Out:
# <PIL.Image.Image image mode=L size=100x100 at 0x7FDA0B770780>

# %%
def convert_image_to_data(image):
    image_resized = Image.open(image).resize((100, 100))
    cat_array = np.array(image_resized).T
    return cat_array

# %%
cat_files = glob.glob("/home/dmadaan/tests/Dogs-vs-Cats/mytrain/cat/cat*")
dog_files = glob.glob("/home/dmadaan/tests/Dogs-vs-Cats/mytrain/dog/dog*")

# %%
cat_list = []
for i in cat_files:
    cat_list.append(convert_image_to_data(i))

# %%
dog_list = []
for i in dog_files:
    dog_list.append(convert_image_to_data(i))

# %%
y_cat = np.zeros(len(cat_list))
print(len(cat_list))
# Out:
# 12500

# %%
y_dog = np.ones(len(dog_list))

# %%
X = np.concatenate([cat_list, dog_list])

# %%
# Cast as float32 type
X = X.astype("float32")

# %%
X
# Out:
# array([[[[  79.,   80.,   83., ...,  118.,  119.,  120.],
#          [  79.,   80.,   83., ...,   94.,  114.,  115.],
#          [  79.,   82.,   83., ...,   70.,   72.,   75.],
#          ...,
#          [ 128.,  130.,  132., ...,   55.,  110.,  117.],
#          [ 128.,  130.,  132., ...,  104.,  115.,  119.],
#          [ 127.,  130.,  129., ...,  106.,  117.,  123.]],
#
#         [[  86.,   86.,   87., ...,  109.,  109.,  110.],
#          [  86.,   86.,   87., ...,   95.,  112.,  113.],
#          [  86.,   88.,   87., ...,   88.,   88.,   91.],
#          ...,
#          [ 130.,  132.,  134., ...,   71.,  110.,  117.],
#          [ 130.,  132.,  134., ...,  109.,  114.,  118.],
#          [ 132.,  135.,  134., ...,  109.,  116.,  122.]],
#
#         [[  78.,   76.,   73., ...,  100.,   97.,   98.],
#          [  78.,   76.,   73., ...,   97.,  100.,  101.],
#          [  78.,   78.,   73., ...,  108.,  103.,  106.],
#          ...,
#          [ 125.,  127.,  129., ...,   68.,  102.,  109.],
#          [ 125.,  127.,  129., ...,  102.,  109.,  113.],
#          [ 126.,  129.,  128., ...,  102.,  112.,  118.]]],
#
#
#        [[[  77.,   51.,   99., ...,    8.,    3.,    7.],
#          [  27.,   29.,   56., ...,    9.,    6.,    8.],
#          [   1.,    0.,    2., ...,   17.,   14.,   10.],
#          ...,
#          [  36.,   41.,   50., ...,   26.,    9.,    4.],
#          [  88.,   92.,   98., ...,    4.,    6.,    1.],
#          [  75.,   76.,   76., ...,    1.,    6.,   12.]],
#
#         [[  48.,   22.,   77., ...,    8.,    3.,    7.],
#          [  21.,   22.,   52., ...,    7.,    4.,    6.],
#          [  19.,   13.,   18., ...,   11.,    8.,    4.],
#          [ 141.,  143.,  144., ...,  127.,  107.,   91.],
#          [ 143.,  144.,  145., ...,  123.,  118.,  118.],
#          ...,
#          [  98.,  100.,  102., ...,  116.,  115.,  111.],
#          [  94.,   96.,   99., ...,  115.,  111.,  108.],
#          [  96.,   93.,   98., ...,  108.,  109.,  107.]],
#
#         [[ 101.,  103.,  104., ...,   59.,   37.,   37.],
#          [  99.,  101.,  102., ...,   81.,   59.,   34.],
#          [ 100.,  101.,  102., ...,   77.,   78.,   69.],
#          ...,
#          [   1.,    1.,    2., ...,   21.,   20.,   16.],
#          [   2.,    2.,    2., ...,   20.,   13.,   10.],
#          [   1.,   12.,    0., ...,   18.,   15.,   13.]]],
#
#
#        [[[ 165.,   85.,   89., ...,  178.,  179.,  180.],
#          [  99.,   18.,   20., ...,  151.,  151.,  152.],
#          [ 103.,   21.,   21., ...,  143.,  142.,  142.],
#          ...,
#          [ 145.,   25.,   26., ...,  150.,  149.,  159.],
#          [ 146.,   26.,   27., ...,  146.,  142.,  149.],
#          [ 148.,   28.,   29., ...,  145.,  139.,  142.]],
#
#         [[ 150.,   70.,   74., ...,  162.,  163.,  164.],
#          [  84.,    3.,    5., ...,  135.,  135.,  136.],
#          [  88.,    6.,    6., ...,  127.,  126.,  126.],
#          ...,
#          [ 124.,    4.,    5., ...,  127.,  126.,  136.],
#          [ 125.,    5.,    6., ...,  123.,  119.,  126.],
#          [ 127.,    7.,    8., ...,  122.,  116.,  119.]],
#
#         [[ 153.,   73.,   77., ...,  191.,  192.,  193.],
#          [  87.,    6.,    8., ...,  164.,  164.,  165.],
#          [  91.,    9.,    9., ...,  156.,  155.,  155.],
#          ...,
#          [ 133.,   13.,   14., ...,  153.,  152.,  162.],
#          [ 134.,   14.,   15., ...,  149.,  145.,  152.],
#          [ 136.,   16.,   17., ...,  148.,  142.,  145.]]]], dtype=float32)

# %%
X.shape
# Out:
# (25000, 3, 100, 100)

# %%
y = np.concatenate([y_cat, y_dog])

# %%
# cast as integer
y = y.astype("int")

# %%
y
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %% [markdown]
# ### Split train data into test/train

# %%
X.shape
# Out:
# (25000, 3, 100, 100)

# %%
y.shape
# Out:
# (25000,)

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=1)

# %%
for train_index, test_index in sss.split(X, y):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
# Out:
# TRAIN: [12111 16593 10771 ...,  5441 14362  9133] TEST: [ 5349 19366  7424 ...,  4349  3098  7545]

# %%
y_train
# Out:
# array([0, 1, 0, ..., 0, 1, 0])

# %%
y_test
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
Counter(y_train), Counter(y_test)
# Out:
# (Counter({0: 10000, 1: 10000}), Counter({0: 2500, 1: 2500}))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %%
y_train, y_test
# Out:
# (array([0, 1, 0, ..., 0, 1, 0]), array([0, 1, 0, ..., 0, 0, 0]))

# %%
Counter(y_train), Counter(y_test)
# Out:
# (Counter({0: 10000, 1: 10000}), Counter({0: 2500, 1: 2500}))

# %% [markdown]
# ### Train model and validate it

# %%
model = Sequential()
# input: 100x100 images with 3 channels -> (3, 100, 100) tensors.
# this applies 32 convolution filters of size 3x3 each.
model.add(Convolution2D(32, 3, 3, border_mode='valid', input_shape=(3, 100, 100)))
model.add(Activation('relu'))
model.add(Convolution2D(32, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Convolution2D(32, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Convolution2D(32, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


model.add(Convolution2D(64, 3, 3, border_mode='valid'))
model.add(Activation('relu'))
model.add(Convolution2D(64, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
# Note: Keras does automatic shape inference.
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(1))
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=32, nb_epoch=2)
# Out:
# Epoch 1/2
# 20000/20000 [==============================] - 46s - loss: 8.0590 - acc: 0.5000
# Epoch 2/2
# 20000/20000 [==============================] - 47s - loss: 8.0590 - acc: 0.5000

# %%
y_test_predict = model.predict(X_test)

# %%
accuracy_score(y_test, y_test_predict)
# Out:
# 0.5
